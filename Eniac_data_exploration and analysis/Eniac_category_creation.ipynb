# %% [markdown]
# # Categorisation pre-work

# %%
import pandas as pd

# %%
# products_clean_df.csv (using our own cleaned-up DataFrame, not from the Notebook/WBS)
url = "https://drive.google.com/file/d/1tI_l4w1Nh5VjovBc60DCLdh1_OnpAXoN/view?usp=sharing"
path = "https://drive.google.com/uc?export=download&id="+url.split("/")[-2]
products_clean_df = pd.read_csv(path)

# %%
product_category_df = products_clean_df.copy()

# %%
#adding new columns and verifying the change
product_category_df["category"] = ""
product_category_df["sub-category"] = ""
product_category_df["condition"] = ""
product_category_df.head(1)
# Out:
#        sku                               name  \
# 0  RAI0007  Silver Rain Design mStand Support
#
#                                            desc  price  in_stock  type  \
# 0  Aluminum support compatible with all MacBook  59.99         1  8696
#
#   category sub-category condition
# 0

# %% [markdown]
# # Dictionaries as categories

# %%
sub_categories_dict = {'12585395': "Adapter",
'5395': "Adapter",
'14365395': "Adapter",
'11434': "Adapter",
'1325': "Adapter",
'1230': "Adapter",
'13955395': "Adapter",
'1231': "Apple Care Protection Plan",
'4259': "Apple TV",
'113464259': "Apple TV",
'24885185': "Apple Watch",
'24895185': "Apple Watch",
'5185': "Apple Watch",
'2449': "Armband",
'5405': "Armband",
'5,49E+11': "Batteries",
'1515': "Batteries",
'10142': "Batteries",
'9094': "Cam & Video",
'1392': "Cases",
'10230': "Cases",
'12575403': "Cases",
'5403': "Cases",
'12635403': "Cases",
'13835403': "Cases",
'11865403': "Cases",
'13615399': "Chargers",
'13005399': "Chargers",
'5399': "Chargers",
'24215399': "Stands & Docks",
'1216': "Stands & Docks",
'5720': "Stands & Docks",
'1405': "Graphic tablets",
'11935397': "Harddrives",
'12655397': "Harddrives",
'12215397': "Harddrives",
'5384': "Headphones & Headsets",
'2,16E+11': "iMac",
'5,74E+15': "iMac",
'118692158': "iMac",
'13855401': "iMac",
'12141714': "iMac",
'1714': "iMac",
'51861714': "iMac",
'5,44E+11': "iMac",
'21622158': "iMac",
'5,45E+15': "iMac",
'5,43E+15': "iMac",
'51882158': "iMac",
'5,72E+15': "iMac",
'13621714': "iPad",
'51871714': "iPad",
'42931714': "iPad",
'24861714': "iPad",
'12031714': "iPad",
'12051714': "iPad",
'113851714': "iPad",
'106431714': "iPad",
'1716': "iPhone",
'85651716': "iPhone",
'85641716': "iPhone",
'24821716': "iPhone",
'24811716': "iPhone",
'113281716': "iPhone",
'113291716': "iPhone",
'21571716': "iPhone",
'21561716': "iPhone",
'113271716': "iPhone",
'51601716': "iPhone",
'11821715': "iPod",
'79201715': "iPod",
'5401': "Keyboard",
'54025401': "Keyboard",
'2,17E+11': "Keyboard",
'21632158': "Mac Pro",
'1282': "MacBook",
'5,39E+11': "MacBook",
'1,02E+12': "MacBook",
'2158': "MacBook",
'9,29E+11': "MacBook",
'51912158': "MacBook",
'51902158': "MacBook",
'1276': "Memory",
'42945397': "Memory",
'57445397': "Memory",
'1364': "Memory",
'1433': "Memory",
'1375': "Microphone",
'1298': "Mixed",
'11905404': "Mixed",
'12995397': "Mixed",
'1404': "Mixed",
'12355400': "Mixed",
'5404': "Mixed",
'101781405': "Mixed",
'1424': "Mixed",
'54085407': "Mixed",
'12085400': "Mixed",
'12285400': "Mixed",
'15435404': "Mixed",
'1296': "Monitor",
'1387': "Mouses",
'1229': "Pens & Pointer",
'2434': "Protectors",
'13555403': "Protectors",
'14035403': "Protectors",
'2425': "Protectors",
'1280': "Rack",
'54864259': "Remote",
'12755395': "Repair",
'20642062': "Repair",
'5407': "Repair",
'21535407': "Repair",
'1,44E+11': "Repair",
'5406': "Repair",
'21485407': "Repair",
'14305406': "Repair",
'12645406': "Repair",
'11859': "Sensor",
'12175397': "Servers",
'1416': "Software",
'5398': "Speakers",
'8696': "Stands & Docks",
'12282': "Stands & Docks",
'1334': "WiFi"}

# %%
product_category_df['sub-category']=product_category_df['type'].replace(sub_categories_dict)

# %%
categories_dict={'12585395': "Accessories",
'5395': "Accessories",
'14365395': "Accessories",
'11434': "Accessories",
'1325': "Accessories",
'1230': "Accessories",
'13955395': "Accessories",
'1231': "Services",
'4259': "Media Player",
'113464259': "Media Player",
'24885185': "Watch",
'24895185': "Watch",
'5185': "Watch",
'2449': "Accessories",
'5405': "Accessories",
'5,49E+11': "Other",
'1515': "Other",
'10142': "Other",
'9094': "Components",
'1392': "Accessories",
'10230': "Accessories",
'12575403': "Accessories",
'5403': "Accessories",
'12635403': "Accessories",
'13835403': "Accessories",
'11865403': "Accessories",
'13615399': "Accessories",
'13005399': "Accessories",
'5399': "Accessories",
'24215399': "Accessories",
'1216': "Accessories",
'5720': "Accessories",
'1405': "Tablet",
'11935397': "Components",
'12655397': "Components",
'12215397': "Components",
'5384': "Components",
'2,16E+11': "Desktop",
'5,74E+15': "Desktop",
'118692158': "Desktop",
'13855401': "Desktop",
'12141714': "Desktop",
'1714': "Desktop",
'51861714': "Desktop",
'5,44E+11': "Desktop",
'21622158': "Desktop",
'5,45E+15': "Desktop",
'5,43E+15': "Desktop",
'51882158': "Desktop",
'5,72E+15': "Desktop",
'13621714': "Tablet",
'51871714': "Tablet",
'42931714': "Tablet",
'24861714': "Tablet",
'12031714': "Tablet",
'12051714': "Tablet",
'113851714': "Tablet",
'106431714': "Tablet",
'1716': "Smartphone",
'85651716': "Smartphone",
'85641716': "Smartphone",
'24821716': "Smartphone",
'24811716': "Smartphone",
'113281716': "Smartphone",
'113291716': "Smartphone",
'21571716': "Smartphone",
'21561716': "Smartphone",
'113271716': "Smartphone",
'51601716': "Smartphone",
'11821715': "Media Player",
'79201715': "Media Player",
'5401': "Components",
'54025401': "Components",
'2,17E+11': "Components",
'21632158': "Desktop",
'1282': "Laptop",
'5,39E+11': "Laptop",
'1,02E+12': "Laptop",
'2158': "Laptop",
'9,29E+11': "Laptop",
'51912158': "Laptop",
'51902158': "Laptop",
'1276': "Components",
'42945397': "Components",
'57445397': "Components",
'1364': "Components",
'1433': "Components",
'1375': "Components",
'1298': "Other",
'11905404': "Other",
'12995397': "Other",
'1404': "Other",
'12355400': "Other",
'5404': "Other",
'101781405': "Other",
'1424': "Other",
'54085407': "Other",
'12085400': "Other",
'12285400': "Other",
'15435404': "Other",
'1296': "Components",
'1387': "Components",
'1229': "Other",
'2434': "Accessories",
'13555403': "Accessories",
'14035403': "Accessories",
'2425': "Accessories",
'1280': "Accessories",
'54864259': "Components",
'12755395': "Services",
'20642062': "Services",
'5407': "Services",
'21535407': "Services",
'1,44E+11': "Services",
'5406': "Services",
'21485407': "Services",
'14305406': "Services",
'12645406': "Services",
'11859': "Security",
'12175397': "Components",
'1416': "Software",
'5398': "Components",
'8696': "Accessories",
'12282': "Accessories",
'1334': "WiFi"}

# %%
product_category_df['category']=product_category_df['type'].replace(categories_dict)

# %% [markdown]
# # Verifying values

# %%
product_category_df.head(10)
# Out:
#          sku                                               name  \
# 0    RAI0007                  Silver Rain Design mStand Support
# 1    APP0023                  Apple Mac Keyboard Keypad Spanish
# 2    APP0025                   Mighty Mouse Apple Mouse for Mac
# 3    APP0072      Apple Dock to USB Cable iPhone and iPod white
# 4    KIN0007        Mac Memory Kingston 2GB 667MHz DDR2 SO-DIMM
# 5    APP0073     Apple Composite AV Cable iPhone and iPod white
# 6    KIN0008        Mac Memory Kingston 1GB 667MHz DDR2 SO-DIMM
# 7    KIN0009        Mac Memory Kingston 2GB 800MHz DDR2 SO-DIMM
# 8  KIN0001-2  Mac memory Kingston 4GB (2x2GB) 667MHz DDR2 SO...
# 9    APP0100             Apple Adapter Mini Display Port to VGA
#
#                                                 desc  price  in_stock  \
# 0       Aluminum support compatible with all MacBook  59.99         1
# 1          USB ultrathin keyboard Apple Mac Spanish.  59.00         0
# ...

# %%
product_category_df["category"].value_counts()
# Out:
# category
# Components      3011
# Accessories     2940
# Other           1706
# Laptop           660
# Desktop          557
# Services         344
# Smartphone       221
# Tablet           163
# Watch            135
# WiFi             115
# Media Player      68
# Software          24
# Security           2
# Name: count, dtype: int64

# %%
#sample code checking after specific product type
product_category_df.loc[product_category_df["type"] == "1405"]
# Out:
#             sku                                               name  \
# 143     WAC0030  Wacom Cintiq 22HD Interactive Pen Display Mac ...
# 368     WAC0090           Wacom Cintiq 13HD Graphic Tablet 13 "LED
# 451     WAC0101                 Wacom Intuos Pro S Graphics Tablet
# 456     WAC0102                 Wacom Intuos Pro M Graphics Tablet
# 457     WAC0104                 Wacom Intuos Pro L Graphics Tablet
# ...         ...                                                ...
# 9915    WAC0252  Education - Wacom Intuos Graphics Tablet S Blu...
# 9916    WAC0254  Education - Wacom Intuos Graphics Tablet S Blu...
# 9917    WAC0256  Education - Wacom Intuos Graphics Tablet M Blu...
# 9918    WAC0258  Education - Wacom Intuos Graphics Tablet M Blu...
# 9926  WAC0163-A  Open - Wacom Intuos graphics tablet Photo Smal...
#
#                                                    desc    price  in_stock  \
# 143   LCD graphic display with 215-inch Full HD and ...  1799.00         0
# ...

# %%
#sample code looking at how many unique product types there are
product_category_df.groupby("type").count().nlargest(125, "sku")
# Out:
#             sku  name  desc  price  in_stock  category  sub-category  \
# type
# 11865403   1057  1057  1057   1057      1057      1057          1057
# 12175397    939   939   939    939       939       939           939
# 1298        783   783   783    783       783       783           783
# 11935397    562   562   562    562       562       562           562
# 11905404    454   454   454    454       454       454           454
# ...         ...   ...   ...    ...       ...       ...           ...
# 21622158      1     1     1      1         1         1             1
# 12282         1     1     1      1         1         1             1
# 5,45E+15      1     1     1      1         1         1             1
# 51912158      1     1     1      1         1         1             1
# 113464259     1     1     1      1         1         1             1
#
#            condition
# type
# 11865403        1057
# 12175397         939
# 1298             783
# 11935397         562
# ...

# %% [markdown]
# # Additional assignments

# %%
#searching sample code:
#product_category_df.loc[product_category_df["desc"].str.contains("keyboard", case=False)]
#product_category_df.loc[product_category_df["name"].str.contains("^.{0,7}apple iphone", case=False)]
#(product_category_df.loc[product_category_df[["desc", "name"]].apply(lambda x: x.str.contains("recorder", case=False)).any(axis=1) &
#                        ~product_category_df[["desc", "name"]].apply(lambda x: x.str.contains("strap", case=False)).any(axis=1)]
#                        .sort_values(by='price', ascending=True))

#assigning sample code:
#product_category_df.loc[product_category_df["desc"].str.contains("keyboard", case=False), "category"] = "keyboard"
#product_category_df.loc[product_category_df["name"].str.contains("^.{0,7}apple iphone", case=False), "category"] = "smartphone"

# %%
product_category_df.loc[product_category_df[["desc", "name"]].apply(lambda x: x.str.contains("^.{0,2}second hand", case=False)).any(axis=1), "condition"] = "Refurbished"

# %%
product_category_df.loc[product_category_df[["desc", "name"]].apply(lambda x: x.str.contains("^.{0,2}open", case=False)).any(axis=1), "condition"] = "Refurbished"

# %%
product_category_df.loc[product_category_df[["desc", "name"]].apply(lambda x: x.str.contains("^.{0,2}like new", case=False)).any(axis=1), "condition"] = "Refurbished"

# %%
product_category_df.loc[product_category_df[["desc", "name"]].apply(lambda x: x.str.contains("r\(open", case=False)).any(axis=1), "condition"] = "Refurbished"

# %%
product_category_df.loc[product_category_df[["condition"]].apply(lambda x: x.str.contains("refurbished", case=False)).any(axis=1), "condition"] = "Opened"

# %%
product_category_df.loc[product_category_df["condition"].str.strip() == "", "condition"] = "New"

# %%
product_category_df.loc[product_category_df[["desc", "name"]].apply(lambda x: x.str.contains("backpack", case=False)).any(axis=1), "sub-category"] = "Backpacks"

# %%
product_category_df.loc[product_category_df[["desc", "name"]].apply(lambda x: x.str.contains("backpack", case=False)).any(axis=1), "category"] = "Accessories"

# %%
(product_category_df.loc[product_category_df[["sub-category"]].apply(lambda x: x.str.contains("mixed", case=False)).any(axis=1) &
                        product_category_df[["name"]].apply(lambda x: x.str.contains("docking station", case=False)).any(axis=1), "sub-category"]) = "Stands & Docks"

# %%
(product_category_df.loc[product_category_df[["sub-category"]].apply(lambda x: x.str.contains("mixed", case=False)).any(axis=1) &
                        product_category_df[["name"]].apply(lambda x: x.str.contains("docking station", case=False)).any(axis=1), "category"]) = "Accessories"

# %%
(product_category_df.loc[product_category_df[["sub-category"]].apply(lambda x: x.str.contains("mixed", case=False)).any(axis=1) &
                        product_category_df[["name"]].apply(lambda x: x.str.contains("apple macbook", case=False)).any(axis=1) &
                        ~product_category_df[["desc"]].apply(lambda x: x.str.contains("charger", case=False)).any(axis=1), "category"]) = "Laptop"

# %%
(product_category_df.loc[product_category_df[["sub-category"]].apply(lambda x: x.str.contains("mixed", case=False)).any(axis=1) &
                        product_category_df[["name"]].apply(lambda x: x.str.contains("apple macbook", case=False)).any(axis=1) &
                        ~product_category_df[["desc"]].apply(lambda x: x.str.contains("charger", case=False)).any(axis=1), "sub-category"]) = "MacBook"

# %%
(product_category_df.loc[product_category_df[["sub-category"]].apply(lambda x: x.str.contains("mixed", case=False)).any(axis=1) &
                        product_category_df[["name"]].apply(lambda x: x.str.contains("apple imac", case=False)).any(axis=1) &
                        ~product_category_df[["desc"]].apply(lambda x: x.str.contains("charger", case=False)).any(axis=1), "category"]) = "Desktop"

# %%
(product_category_df.loc[product_category_df[["sub-category"]].apply(lambda x: x.str.contains("mixed", case=False)).any(axis=1) &
                        product_category_df[["name"]].apply(lambda x: x.str.contains("apple imac", case=False)).any(axis=1) &
                        ~product_category_df[["desc"]].apply(lambda x: x.str.contains("charger", case=False)).any(axis=1), "sub-category"]) = "iMac"

# %%
(product_category_df.loc[product_category_df[["sub-category"]].apply(lambda x: x.str.contains("mixed", case=False)).any(axis=1) &
                        product_category_df[["name"]].apply(lambda x: x.str.contains("graphics tablet", case=False)).any(axis=1) &
                        ~product_category_df[["desc"]].apply(lambda x: x.str.contains("charger", case=False)).any(axis=1), "category"]) = "Tablet"

# %%
(product_category_df.loc[product_category_df[["sub-category"]].apply(lambda x: x.str.contains("mixed", case=False)).any(axis=1) &
                        product_category_df[["name"]].apply(lambda x: x.str.contains("apple imac", case=False)).any(axis=1) &
                        ~product_category_df[["desc"]].apply(lambda x: x.str.contains("charger", case=False)).any(axis=1), "sub-category"]) = "Graphic tablets"

# %%
(product_category_df.loc[product_category_df[["sub-category"]].apply(lambda x: x.str.contains("mixed", case=False)).any(axis=1) &
                        product_category_df[["name"]].apply(lambda x: x.str.contains("apple mac mini", case=False)).any(axis=1) &
                        ~product_category_df[["desc"]].apply(lambda x: x.str.contains("charger", case=False)).any(axis=1), "category"]) = "Desktop"

# %%
(product_category_df.loc[product_category_df[["sub-category"]].apply(lambda x: x.str.contains("mixed", case=False)).any(axis=1) &
                        product_category_df[["name"]].apply(lambda x: x.str.contains("apple mac mini", case=False)).any(axis=1) &
                        ~product_category_df[["desc"]].apply(lambda x: x.str.contains("charger", case=False)).any(axis=1), "sub-category"]) = "iMac"

# %%
(product_category_df.loc[product_category_df[["sub-category"]].apply(lambda x: x.str.contains("mixed", case=False)).any(axis=1) &
                        product_category_df[["desc"]].apply(lambda x: x.str.contains("monitor", case=False)).any(axis=1) &
                        (product_category_df["price"] >= 500),"category"]) = "Components"

# %%
(product_category_df.loc[product_category_df[["sub-category"]].apply(lambda x: x.str.contains("mixed", case=False)).any(axis=1) &
                        product_category_df[["desc"]].apply(lambda x: x.str.contains("monitor", case=False)).any(axis=1) &
                        (product_category_df["price"] >= 500),"sub-category"]) = "Monitor"

# %%
(product_category_df.loc[product_category_df[["sub-category"]].apply(lambda x: x.str.contains("mixed", case=False)).any(axis=1) &
                        product_category_df[["desc"]].apply(lambda x: x.str.contains("graphics tablet", case=False)).any(axis=1),"category"]) = "Tablet"

# %%
(product_category_df.loc[product_category_df[["sub-category"]].apply(lambda x: x.str.contains("mixed", case=False)).any(axis=1) &
                        product_category_df[["desc"]].apply(lambda x: x.str.contains("graphics tablet", case=False)).any(axis=1),"sub-category"]) = "Graphic tablets"

# %%
(product_category_df.loc[product_category_df[["sub-category"]].apply(lambda x: x.str.contains("mixed", case=False)).any(axis=1) &
                        product_category_df[["name"]].apply(lambda x: x.str.contains("apple ipad", case=False)).any(axis=1) &
                        (product_category_df["price"] >= 300),"category"]) = "Tablet"

# %%
(product_category_df.loc[product_category_df[["sub-category"]].apply(lambda x: x.str.contains("mixed", case=False)).any(axis=1) &
                        product_category_df[["name"]].apply(lambda x: x.str.contains("apple ipad", case=False)).any(axis=1) &
                        (product_category_df["price"] >= 300),"sub-category"]) = "iPad"

# %%
(product_category_df.loc[product_category_df[["sub-category"]].apply(lambda x: x.str.contains("mixed", case=False)).any(axis=1) &
                        product_category_df[["desc"]].apply(lambda x: x.str.contains("expansion", case=False)).any(axis=1) &
                        (product_category_df["price"] >= 300),"category"]) = "Components"

# %%
(product_category_df.loc[product_category_df[["sub-category"]].apply(lambda x: x.str.contains("mixed", case=False)).any(axis=1) &
                        product_category_df[["desc"]].apply(lambda x: x.str.contains("expansion", case=False)).any(axis=1) &
                        (product_category_df["price"] >= 300),"sub-category"]) = "Harddrives"

# %%
(product_category_df.loc[product_category_df[["sub-category"]].apply(lambda x: x.str.contains("mixed", case=False)).any(axis=1) &
                        product_category_df[["desc"]].apply(lambda x: x.str.contains("smartwatch", case=False)).any(axis=1) &
                        (product_category_df["price"] >= 30),"category"]) = "Watch"

# %%
(product_category_df.loc[product_category_df[["sub-category"]].apply(lambda x: x.str.contains("mixed", case=False)).any(axis=1) &
                        product_category_df[["desc"]].apply(lambda x: x.str.contains("smartwatch", case=False)).any(axis=1) &
                        (product_category_df["price"] >= 30),"sub-category"]) = "Smartwatch"

# %%
(product_category_df.loc[product_category_df[["sub-category"]].apply(lambda x: x.str.contains("mixed", case=False)).any(axis=1) &
                        product_category_df[["desc"]].apply(lambda x: x.str.contains("smart watch", case=False)).any(axis=1) &
                        (product_category_df["price"] >= 30),"category"]) = "Watch"

# %%
(product_category_df.loc[product_category_df[["sub-category"]].apply(lambda x: x.str.contains("mixed", case=False)).any(axis=1) &
                        product_category_df[["desc"]].apply(lambda x: x.str.contains("smart watch", case=False)).any(axis=1) &
                        (product_category_df["price"] >= 30),"sub-category"]) = "Smartwatch"

# %%
(product_category_df.loc[product_category_df[["sub-category"]].apply(lambda x: x.str.contains("mixed", case=False)).any(axis=1) &
                        product_category_df[["desc"]].apply(lambda x: x.str.contains("hard drive", case=False)).any(axis=1) &
                        (product_category_df["price"] >= 30),"category"]) = "Components"

# %%
(product_category_df.loc[product_category_df[["sub-category"]].apply(lambda x: x.str.contains("mixed", case=False)).any(axis=1) &
                        product_category_df[["desc"]].apply(lambda x: x.str.contains("hard drive", case=False)).any(axis=1) &
                        (product_category_df["price"] >= 30),"sub-category"]) = "Harddrives"

# %%
(product_category_df.loc[product_category_df[["sub-category"]].apply(lambda x: x.str.contains("mixed", case=False)).any(axis=1) &
                        product_category_df[["desc"]].apply(lambda x: x.str.contains("protective", case=False)).any(axis=1),"category"]) = "Accessories"

# %%
(product_category_df.loc[product_category_df[["sub-category"]].apply(lambda x: x.str.contains("mixed", case=False)).any(axis=1) &
                        product_category_df[["desc"]].apply(lambda x: x.str.contains("protective", case=False)).any(axis=1),"sub-category"]) = "Cases"

# %%
(product_category_df.loc[product_category_df[["sub-category"]].apply(lambda x: x.str.contains("mixed", case=False)).any(axis=1) &
                        product_category_df[["desc"]].apply(lambda x: x.str.contains("housing", case=False)).any(axis=1) &
                        (product_category_df["price"] >= 230),"category"]) = "Accessories"

# %%
(product_category_df.loc[product_category_df[["sub-category"]].apply(lambda x: x.str.contains("mixed", case=False)).any(axis=1) &
                        product_category_df[["desc"]].apply(lambda x: x.str.contains("housing", case=False)).any(axis=1) &
                        (product_category_df["price"] >= 230),"sub-category"]) = "Protectors"

# %%
(product_category_df.loc[product_category_df[["sub-category"]].apply(lambda x: x.str.contains("mixed", case=False)).any(axis=1) &
                        product_category_df[["desc"]].apply(lambda x: x.str.contains("housing", case=False)).any(axis=1),"category"]) = "Accessories"

# %%
(product_category_df.loc[product_category_df[["sub-category"]].apply(lambda x: x.str.contains("mixed", case=False)).any(axis=1) &
                        product_category_df[["desc"]].apply(lambda x: x.str.contains("housing", case=False)).any(axis=1),"sub-category"]) = "Cases"

# %%
(product_category_df.loc[product_category_df[["sub-category"]].apply(lambda x: x.str.contains("mixed", case=False)).any(axis=1) &
                        product_category_df[["desc"]].apply(lambda x: x.str.contains("two-wheeled", case=False)).any(axis=1),"sub-category"]) = "Transport"

# %%
(product_category_df.loc[product_category_df[["sub-category"]].apply(lambda x: x.str.contains("mixed", case=False)).any(axis=1) &
                        product_category_df[["desc"]].apply(lambda x: x.str.contains("two-wheeled", case=False)).any(axis=1),"category"]) = "Other"

# %%
(product_category_df.loc[product_category_df[["sub-category"]].apply(lambda x: x.str.contains("mixed", case=False)).any(axis=1) &
                        product_category_df[["desc"]].apply(lambda x: x.str.contains("scooter", case=False)).any(axis=1),"sub-category"]) = "Transport"

# %%
(product_category_df.loc[product_category_df[["sub-category"]].apply(lambda x: x.str.contains("mixed", case=False)).any(axis=1) &
                        product_category_df[["desc"]].apply(lambda x: x.str.contains("scooter", case=False)).any(axis=1),"category"]) = "Other"

# %%
(product_category_df.loc[product_category_df[["sub-category"]].apply(lambda x: x.str.contains("mixed", case=False)).any(axis=1) &
                        product_category_df[["desc"]].apply(lambda x: x.str.contains("iphone", case=False)).any(axis=1) &
                        (product_category_df["price"] >= 400),"category"]) = "Smartphone"

# %%
(product_category_df.loc[product_category_df[["sub-category"]].apply(lambda x: x.str.contains("mixed", case=False)).any(axis=1) &
                        product_category_df[["desc"]].apply(lambda x: x.str.contains("iphone", case=False)).any(axis=1) &
                        (product_category_df["price"] >= 400),"sub-category"]) = "iPhone"

# %%
(product_category_df.loc[product_category_df[["sub-category"]].apply(lambda x: x.str.contains("mixed", case=False)).any(axis=1) &
                        product_category_df[["desc"]].apply(lambda x: x.str.contains("server", case=False)).any(axis=1) &
                        (product_category_df["price"] >= 300),"category"]) = "Components"

# %%
(product_category_df.loc[product_category_df[["sub-category"]].apply(lambda x: x.str.contains("mixed", case=False)).any(axis=1) &
                        product_category_df[["desc"]].apply(lambda x: x.str.contains("server", case=False)).any(axis=1) &
                        (product_category_df["price"] >= 300),"sub-category"]) = "Servers"

# %%
(product_category_df.loc[product_category_df[["sub-category"]].apply(lambda x: x.str.contains("mixed", case=False)).any(axis=1) &
                        product_category_df[["desc"]].apply(lambda x: x.str.contains("external", case=False)).any(axis=1) &
                        (product_category_df["price"] >= 300),"category"]) = "Components"

# %%
(product_category_df.loc[product_category_df[["sub-category"]].apply(lambda x: x.str.contains("mixed", case=False)).any(axis=1) &
                        product_category_df[["desc"]].apply(lambda x: x.str.contains("external", case=False)).any(axis=1) &
                        (product_category_df["price"] >= 300),"sub-category"]) = "Memory"

# %%
(product_category_df.loc[product_category_df[["sub-category"]].apply(lambda x: x.str.contains("mixed", case=False)).any(axis=1) &
                        product_category_df[["desc"]].apply(lambda x: x.str.contains("camera", case=False)).any(axis=1) &
                        (product_category_df["price"] >= 300),"category"]) = "Components"

# %%
(product_category_df.loc[product_category_df[["sub-category"]].apply(lambda x: x.str.contains("mixed", case=False)).any(axis=1) &
                        product_category_df[["desc"]].apply(lambda x: x.str.contains("camera", case=False)).any(axis=1) &
                        (product_category_df["price"] >= 300),"sub-category"]) = "Cam & Video"

# %%
(product_category_df.loc[product_category_df[["sub-category"]].apply(lambda x: x.str.contains("mixed", case=False)).any(axis=1) &
                        product_category_df[["desc"]].apply(lambda x: x.str.contains("monitor", case=False)).any(axis=1) &
                        (product_category_df["price"] >= 300),"category"]) = "Components"

# %%
(product_category_df.loc[product_category_df[["sub-category"]].apply(lambda x: x.str.contains("mixed", case=False)).any(axis=1) &
                        product_category_df[["desc"]].apply(lambda x: x.str.contains("monitor", case=False)).any(axis=1) &
                        (product_category_df["price"] >= 300),"sub-category"]) = "Monitor"

# %%
(product_category_df.loc[product_category_df[["sub-category"]].apply(lambda x: x.str.contains("mixed", case=False)).any(axis=1) &
                        product_category_df[["desc"]].apply(lambda x: x.str.contains("dock", case=False)).any(axis=1) &
                        (product_category_df["price"] >= 300),"category"]) = "Accessories"

# %%
(product_category_df.loc[product_category_df[["sub-category"]].apply(lambda x: x.str.contains("mixed", case=False)).any(axis=1) &
                        product_category_df[["desc"]].apply(lambda x: x.str.contains("dock", case=False)).any(axis=1) &
                        (product_category_df["price"] >= 300),"sub-category"]) = "Stands & Docks"

# %%
(product_category_df.loc[product_category_df[["sub-category"]].apply(lambda x: x.str.contains("mixed", case=False)).any(axis=1) &
                        product_category_df[["desc"]].apply(lambda x: x.str.contains("disk", case=False)).any(axis=1) &
                        (product_category_df["price"] >= 300),"category"]) = "Components"

# %%
(product_category_df.loc[product_category_df[["sub-category"]].apply(lambda x: x.str.contains("mixed", case=False)).any(axis=1) &
                        product_category_df[["desc"]].apply(lambda x: x.str.contains("disk", case=False)).any(axis=1) &
                        (product_category_df["price"] >= 300),"sub-category"]) = "Harddrives"

# %% [markdown]
# ## Searches

# %%
#sample code resused for searching
product_category_df.loc[product_category_df[["sub-category"]].apply(lambda x: x.str.contains("mixed", case=False)).any(axis=1) &
                        product_category_df[["desc"]].apply(lambda x: x.str.contains("disk", case=False)).any(axis=1) &
                        (product_category_df["price"] >= 300)].sort_values(by='price', ascending=False)
# Out:
# Empty DataFrame
# Columns: [sku, name, desc, price, in_stock, type, category, sub-category, condition]
# Index: []

# %%
#checking to see status of "mixed" sub-category for anything that could be recategorized
product_category_df.loc[product_category_df[["sub-category"]].apply(lambda x: x.str.contains("mixed", case=False)).any(axis=1)].sort_values(by='price', ascending=False)
# Out:
#             sku                                               name  \
# 5993  WAC0024-A  Open - Wacom Cintiq 22HD Interactive Pen Displ...
# 3631    PAR0065           Parrot Bebop Drone + 2 Red Skycontroller
# 3639    PAR0064         Parrot Bebop Drone White 2 + SkyController
# 8452    NIE0011  Ninebot by Segway One E + Electric Unicycle White
# 6911    SNN0054  Sonnet Twin 10G SFP + 10G SFP + adapter chassi...
# ...         ...                                                ...
# 1069    PAR0027      Parrot Central Cross Rolling Spider MiniDrone
# 4043    IHE0025  iHealth 50 lancets Set Compatible for glucímetros
# 4267    WAC0190     Gen 2 Wacom tips Only parts and Duo CS-160/170
# 612     WAC0127       Wacom Bamboo Stylus Pack 3 tips Solo and Duo
# 1072    PAR0037     Upper body MiniDrone Parrot Jumping Sumo White
#
#                                                    desc    price  in_stock  \
# 5993  portable graphic display with pen presición fo...  1799.00         0
# ...

# %%
product_category_df["sub-category"].value_counts()
# Out:
# sub-category
# Cases                         1823
# Mixed                         1074
# Harddrives                     975
# Servers                        948
# MacBook                        681
# Memory                         585
# iMac                           530
# Adapter                        503
# Repair                         334
# iPhone                         238
# Stands & Docks                 224
# Monitor                        216
# Headphones & Headsets          178
# Speakers                       159
# Batteries                      153
# Armband                        146
# Apple Watch                    135
# Protectors                     130
# Chargers                       129
# WiFi                           115
# Pens & Pointer                 104
# iPad                            98
# Graphic tablets                 90
# iPod                            61
# Backpacks                       60
# Cam & Video                     55
# ...

# %%
product_category_df["category"].value_counts()
# Out:
# category
# Components      3199
# Accessories     3010
# Other           1346
# Laptop           681
# Desktop          567
# Services         344
# Smartphone       238
# Tablet           190
# Watch            162
# WiFi             115
# Media Player      68
# Software          24
# Security           2
# Name: count, dtype: int64

# %%
product_category_df.shape
# Out:
# (9992, 9)

# %% [markdown]
# # Exporting categorized products DataFrame as .csv

# %%
#mounting Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#saving the categorized products DataFrame as .cvs
product_category_df.to_csv('/content/drive/MyDrive/Colab Notebooks/Eniac/Eniac_exploration_cleaning/products_categorized_df.csv', index=False)

# %%
#verifying copying was successful
df_verify = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Eniac/Eniac_exploration_cleaning/products_categorized_df.csv')
print(df_verify)
# Out:
#           sku                                           name  \
# 0     RAI0007              Silver Rain Design mStand Support
# 1     APP0023              Apple Mac Keyboard Keypad Spanish
# 2     APP0025               Mighty Mouse Apple Mouse for Mac
# 3     APP0072  Apple Dock to USB Cable iPhone and iPod white
# 4     KIN0007    Mac Memory Kingston 2GB 667MHz DDR2 SO-DIMM
# ...       ...                                            ...
# 9987  BEL0376        Belkin Travel Support Apple Watch Black
# 9988  THU0060   Enroute Thule 14L Backpack MacBook 13 "Black
# 9989  THU0061    Enroute Thule 14L Backpack MacBook 13 "Blue
# 9990  THU0062     Enroute Thule 14L Backpack MacBook 13 "Red
# 9991  THU0063   Enroute Thule 14L Backpack MacBook 13 "Green
#
#                                                    desc  price  in_stock  \
# 0          Aluminum support compatible with all MacBook  59.99         1
# 1             USB ultrathin keyboard Apple Mac Spanish.  59.00         0
# ...
